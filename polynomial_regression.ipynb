# %% [markdown]
# <a href="https://colab.research.google.com/github/sarahasan17/machine_learning/blob/main/polynomial_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Polynomial Regression

# %% [markdown]
# ## Importing the libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Importing the dataset

# %%
dataset=pd.read_csv('Position_Salaries.csv')
X=dataset.iloc[:,1:-1].values#independent
Y=dataset.iloc[:,-1].values#dependent

# %% [markdown]
# ## Training the Linear Regression model on the whole dataset

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(X,Y)
# Out:
# LinearRegression()

# %% [markdown]
# ## Training the Polynomial Regression model on the whole dataset

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_reg=PolynomialFeatures(degree=5)#as the degree increaes the plotting is more accurate
X_cord=poly_reg.fit_transform(X)
regressor1=LinearRegression()
regressor1.fit(X_cord,Y)
# Out:
# LinearRegression()

# %% [markdown]
# ## Visualising the Linear Regression results

# %%
plt.scatter(X,Y,color='red')
plt.plot(X,regressor.predict(X),color="blue")
plt.title('level vs salary')
plt.xlabel('level')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# ## Visualising the Polynomial Regression results

# %%
plt.scatter(X,Y,color='red')
plt.plot(X,regressor1.predict(X_cord),color="blue")
plt.title('level vs salary(Polynomial Regression)')
plt.xlabel('level')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# ## Visualising the Polynomial Regression results (for higher resolution and smoother curve)

# %%
X_grid = np.arange(min(X), max(X), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X, Y, color = 'red')
plt.plot(X_grid, regressor1.predict(poly_reg.fit_transform(X_grid)), color = 'blue')
plt.title('Truth or Bluff (Polynomial Regression)')
plt.xlabel('Position level')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# ## Predicting a new result with Linear Regression

# %%
regressor.predict([[5]])#[] corresponds to row [[]] corresponds to column
# Out:
# array([209060.60606061])

# %% [markdown]
# ## Predicting a new result with Polynomial Regression

# %%
regressor1.predict(poly_reg.fit_transform([[5]]))
# Out:
# array([112263.40326412])
