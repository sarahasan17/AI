# %% [markdown]
# <a href="https://colab.research.google.com/github/sarahasan17/AI/blob/main/wave_plot_audio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import wave
import matplotlib.pyplot as plt
import numpy as np

# %%
wav_obj = wave.open('Sara voice.wav', 'r')

# %%
sample_freq = wav_obj.getframerate()
print(sample_freq)

n_samples = wav_obj.getnframes()
print(n_samples)

t_audio = n_samples / sample_freq
print(t_audio, "seconds")
# Out:
# 48000
# 164864
# 3.4346666666666668 seconds

# %%
# Read frames for both channels
signal_wave = wav_obj.readframes(n_samples)
signal_array_stereo = np.frombuffer(signal_wave, dtype=np.int16)

# %%
# Take only one channel (e.g., left channel)
signal_array_mono = signal_array_stereo[::2]

# Generate times array based on the total duration of the audio
times = np.linspace(0, t_audio, num=n_samples)

plt.figure(figsize=(15, 5))
plt.plot(times, signal_array_mono)
plt.title('Audio')
plt.ylabel('Signal Value')
plt.xlabel('Time (s)')
plt.xlim(0, t_audio)
plt.show()
